# %%
import os
import sys
import pandas as pd

# Allow notebook to access src/
sys.path.append(os.path.abspath(".."))

from src.nlp.text_cleaning import clean_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dhanya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dhanya\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dhanya\AppData\Roaming\nltk_data...

# %%
df = pd.read_csv("../data/processed/resumes_raw.csv")

# %%
df["clean_text"] = df["resume_text"].apply(clean_text)

# %%
df[["resume_text", "clean_text"]].head(3)
# Out:
#                                          resume_text  \
# 0  Name: Ravali P                                ...
# 1     SUSOVAN  BAG    Seeking  a  challenging  po...
# 2    Anubhav Kumar Singh\t\t    To work in a glob...
#
#                                           clean_text
# 0  name ravali curriculum vitae specialization co...
# 1  susovan bag seeking challenging position field...
# 2  anubhav kumar singh work globally competitive ...

# %%
df["clean_text"].str.len().describe()
# Out:
# count       53.000000
# mean      3023.679245
# std       1875.748628
# min        792.000000
# 25%       1763.000000
# 50%       2747.000000
# 75%       3551.000000
# max      11573.000000
# Name: clean_text, dtype: float64

# %%
df = df[df["clean_text"].str.len() > 0]
df.reset_index(drop=True, inplace=True)

# %%
OUTPUT_PATH = "../data/processed/resumes_cleaned.csv"

df.to_csv(OUTPUT_PATH, index=False)

print(f"✅ Cleaned dataset saved at: {OUTPUT_PATH}")
# Out:
# ✅ Cleaned dataset saved at: ../data/processed/resumes_cleaned.csv
